# %%
import boto3

s3 = boto3.client(
    's3',
    aws_access_key_id="aae22ae10540cf0081380110bbbdd6b2",
    aws_secret_access_key="XXX",
    endpoint_url="https://golucliredxdcemqhwsw.storage.supabase.co/storage/v1/s3"
)

try:
    response = s3.list_objects_v2(Bucket="mlflow-artifacts", MaxKeys=1)
    print("Accès S3 OK !", response)
except Exception as e:
    print("Erreur S3 :", e)
# Out:
# Accès S3 OK ! {'ResponseMetadata': {'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Tue, 24 Feb 2026 21:28:08 GMT', 'content-type': 'application/xml; charset=utf-8', 'content-length': '633', 'connection': 'keep-alive', 'server': 'cloudflare', 'cf-ray': '9d320d0d8dd4d0af-CDG', 'cf-cache-status': 'DYNAMIC', 'access-control-allow-origin': '*', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'x-content-type-options': 'nosniff', 'sb-gateway-mode': 'direct', 'sb-gateway-version': '1', 'sb-project-ref': 'golucliredxdcemqhwsw', 'sb-request-id': '019c918d-647a-7f4c-8a32-37d8148757c3', 'set-cookie': '__cf_bm=RIEO9E6rlWyi1Eew2IsTBlvownLbcDmJ7Aub9ddZNHg-1771968488-1.0.1.1-VDx6D1nqQ02AgAEYSX6GLcg7IG5bzRCFD1tagqA4X9EjWbVDjb388frwjkX_5cU1y.lG1vFpQg13e2obwHSE6a6QeYm8xzoRLAj0kRZtJNE; path=/; expires=Tue, 24-Feb-26 21:58:08 GMT; domain=.storage.supabase.co; HttpOnly; Secure; SameSite=None', 'vary': 'Accept-Encoding'}, 'RetryAttempts': 0}, 'IsTruncated': True, 'Contents': [
# ...
